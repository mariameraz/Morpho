# %% [markdown]
# # <div style='text-align: center'> Tutorial: Fruit Internal Structure Analysis Using Slice Images</div>
# ***<div style = 'color:#696969; text-align: center'>Last update: July 21, 2025. </div>***
# <div style='text-align: center'>
#   <a href="mailto:ma.torresmeraz@gmail.com" style="color: #48D1CC; text-decoration: none;">
#     ma.torresmeraz@gmail.com
#   </a>
# </div>
#
#
# <br>

# %% [markdown]
# Basic locule segmentation

# %%
# Import modules
from morphoslicer.internal_structure import AnalyzingImage

# %%
path_img = '/Users/alejandra/Documents/Pictures/Scans/cranberry3.jpg'
image_analysis = AnalyzingImage(path_img)

# %%
image_analysis.read_image(plot = True, plot_size = (8,8))
# Out:
# cranberry3.jpg successfully loaded ✧*｡

# %%
image_analysis.create_mask(plot = True, plot_size = (8,8), n_kernel = 3)

# %%
image_analysis.find_fruits()
# Out:
# Total detected objects: 361
# Detected fruits after filtering: 13

# %%
image_analysis.analyze_image(plot=True, plot_size = (20,20), font_scale = 3, min_distance = 30, max_distance = 40, contour_mode = 'raw')
